# %%
from random import shuffle, randint

score1 = 0
score2 = 0
team1 = ''
team2 = ''
n = 0

acceptable_difficulty = ['easy', 'medium', 'hard']

difficulty_points = {
        'easy' : 10,
        'medium': 20,
        'hard': 50
    }



pw = {'easy': [
    'Solve a•b, when abs(a)= 2, abs(b)= 3, cosθ= 0.5 |3', 
    'What is the formula derived from Newtons first law? |F=ma',
    'What are the SI units for angular velocity? |rad/s', 
    'Evaluate (-3i + 5j - k)•(2i - 3j - 8k) |-13', 
    'What is the formula for angular acceleration? |dω/dt', 
    'What are the forces acting on a rolling cart down a slope, assuming the wheels roll without slipping? |Gravitational force, normal force, static friction',
    'Two objects, A and B, are pushed on a frictionless surface from a starting line to a finish line with equal constant forces. A is four times as massive as B. Both objects are initially at rest. Kinetic energy of A __ B. Fill in the blank with >, < or =. |=',
    'You toss a ball straight upward, in the positive direction. The ball falls freely under the influence of gravity. velocity of ball = ___ |0', 
    'Work done is a form of energy. True or false? |False', 
    '2 balls, A and B, with masses 4m and 6m are rolling towards you. You exert the same force to stop them. Which ball requires more distance to come to a rest? |A'
],
     'medium': [
    'A person is standing in an elevator accelerating upwards. The upward normal force N exerted by the elevator floor on the person is ______ the downward force of gravity on the person. Fill in the balck with larger than, smaller than or identical to.|larger than',
    'The amount of energy required to accelerate a car from rest to 10 km/h is x Joules. How much energy is required to accelerate the same car from 10 km/h to 20 km/h? |4x J', 
    'A car goes 2 complete rounds around a 30km track in 40 mins. What is the cars average velocity in m/s? |0', 
    'A beam of length 2m is balanced on a pivot point that is placed directly beneath the center of the beam. An object of mass of 0.4 kg is placed a distance d1 to the right of the pivot point. A second object of mass of 0.6 kg is placed a distance d2 to the left of the pivot point to keep the beam static. What is the distance d2 that maintains static equilibrium? Leave your answer in terms of d1. |2/3 d1', 
    'Find the vertical displacement of a projectile with initial speed and final speed at 8.5m/s and 9m/s respectively, at time, t= 6s. Leave you answer in terms of g. |(51 + 9g)m',
    'A car of mass 1700 kg is making a sharp corner of 100 m in radius with a constant speed of 65 km/h. The driver suddenly realizes the presence of an LTA officer nearby, and he quickly slows his car to a speed of 20 km/h in 2.0 s with constant angular deceleration. Assume that the car is a point mass. What is the moment of inertia of the car with respect to the center of the rotation? |1.7 x 10^7 kg/m^2', 
    'Consider a thin uniform rod of length L and mass M. Calculate the moment of inertia about the axis that passes the rod perpendicularly through its edge. |ML^2/12', 
    'A particle is moving in a circle of radius 𝑅. At 𝑡= 0, it is located on the x‐axis. The angle the particle makes with the positive x‐axis is given by 𝜃 𝑡= At - Bt^3, where 𝐴 and 𝐵 are positive constants. Determine the angular speed. |A-3Bt^2', 
    'A ball is thrown upwards 1.3m with a force of 2.9N. What is the work done by gravity on the ball? |-3.77J', 
    'If a wheel of radius R rolls without slipping through an angle Δθ, what is the relationship between the distance the wheel rolls, Δx, and the product RΔθ? Δx__RΔθ. Fill in the blank with >, < or =. |='
],
     'hard': [
    'Solve for k:  3abs(i+kj)=2abs(i-2kj) ( I and j are direction vectors)|plus or minus √(5/7)',
    'A light spring with a force constant k is suspended from the ceiling. A block of mass m is attached to it. Initially, the block is held so that the spring is not stretched. The block is then released. What is the maximum elongation of the spring in the subsequent motion of the block? |2mg/k', 
    'A car of mass 1700 kg is making a sharp corner of 100 m in radius with a constant speed of 65 km/h. The driver suddenly realizes the presence of an LTA officer nearby, and he quickly slows his car to a speed of 20 km/h in 2.0 s with constant angular deceleration. Assume that the car is a point mass. What is the angular deceleration of the car while it is slowing down? |-0.0625 rad/s^2', 
    'A block of mass m is blown up a hill by wind acting on it. The hill has a circular shape of radius R. The force of the wind has a constant magnitude F and is parallel to the horizontal as shown in the figure. What is the work done by the wind on the block after it has moved from the bottom to the top of the hill? |FR', 
    'A uniform beam of length L and mass m is hinged to a wall at one end and suspended from the wall by a cable that is attached to the other end of the beam at an angle of β as shown in the figure. Assume the cable has zero mass. There is a contact force on the beam at the pivot point between the beam and the wall. The magnitude F and direction of this pivot force is unknown. What is the tension in the cable? |mg/2sinβ',
    'A light plane of mass M = 1000 kg makes an emergency landing on a short runway. With its engine off, it lands on the runway at a speed of u0 = 40 ms‐1. A hook on the plane snags a cable attached to a sandbag of mass m = 120 kg and drags the sandbag along. If the coefficient of friction between the sandbag and the runway is μ = 0.4, and if the plane’s brakes give an additional retarding force of magnitude Fd = 1400 N, how far does the plane go before it comes to a stop? |382m', 
    'A wheel is connected via a pulley to a motor. A thread is knotted and placed through a hole in a ping pong ball of mass m. A wing nut secures the thread holding the ball a distance R from the center of the wheel. The wheel is set in motion. When a satisfactory angular speed ω is reached, the string is cut and the ball comes off at a tangent to the spinning wheel, traveling vertically upward a distance h. Find the angular speed of the rotating wheel just before the string is cut. |(2gh)^0.5/R', 
    'Mountaineers often use a rope to lower themselves down the face of a cliff (this is called rappelling). They do this with their body nearly horizontal and their feet pushing against the cliff. Suppose that an 82.0 kg climber, who is 1.90 m tall and has a center of gravity 1.1 m from his feet, rappels down a vertical cliff with his body raised 35.0° above the horizontal. He holds the rope close to his body at 1.40 m from his feet, and it makes a 25.0° angle with the cliff face. What tension does his rope need to support? The gravitational acceleration can be taken as g = 9.80 m/s^2. |525N', 
    'A block of mass 𝑚 slides up an inclined plane with an initial speed 𝑣. The block slides a distance 𝑑 before coming to a stop. The inclined plane makes an angle of 𝜃 from the horizontal. Let the coefficient of kinetic friction between the block and the inclined plane be 𝜇 and the acceleration due to gravity be 𝑔. |𝑚𝑔𝑑 sin 𝜃', 
    'A block of mass 𝑚1 = 6 kg is hanging by a massless cord connected to another block of mass 𝑚2 = 4 kg, which is also hanging by a different massless cord. What is the tension in both cords when the system is at rest? Leave your answer in terms of g |10g']

     }

shuffle(pw['easy'])
shuffle(pw['medium'])
shuffle(pw['hard'])

ma = {'easy': [
    'What is the symbol used for set of all rational numbers?|Q', 
    'If the domain and codomain of function f is A and B respectively, and the domain and codomain of function g is C and D respectively, what is the criteria for the composite g•f to exist?|The range of f must be a subset of domain of g.', 
    'What is the criteria of even functions?|f(-x)=f(x)', 
    'What is the criteria for odd functions?|f(-x)=-f(x)', 
    'True or False: If f(x) is continuous on the open interval (a,b) and differentiable in the open interval [a,b], there exists a c in [a,b] such that f prime(c)= (f(b)-f(a))/(b-a)|False', 
    'True or False:  f(x)=abs(x) is differentiable in (-2,2)? |False', 
    'True or False: ∞ x ∞ = indeterminate|False', 
    'For complex number i=? |square root of -1', 
    'For complex number i=? |square root of -1', 
    'differentiate a^x wrt x|(a^x)ln(a)’, ‘simplify arg( z^n) |n arg(z)'
],
     'medium': [
         'Complete the blank: If f(x) is continuous in [a,b] and differentiable on (a,b) with f(a)=f(b), then there exists a c with f prime (c)=___|0', 
         'Where are the critical points of a function located?|f prime (x)=0, f prime(x)= undefined, end points', 
         'Integrate (cos x)^2 wrt x|(sin2x/2 +x)/2 + C', 
         'Would the area under the graph of f(x)=x^2 from x=2 to x=4 using Reimanns left-hand rule be an overestimate or an underestimate? Explain.|Underestimate since f is increasing in this interval.',
         'Integration of cos x from x=-a to x=a|0', 
         'Integration of tan x wrt x |In |sec x| + c', 
         'State the conditions of a function to use EVT|The function must be continuous on a closed interval', 
         'True or False: All rational functions are continuous. |True',
         'Fill in the blanks with <,>, ≤,≥. For a<b, if the function f(x) is non-decreasing, f(a)__ f(b)|≤',
         'f(x) and f inverse (x) are reflections of each other about the line ___. |y=x'
     ],
     'hard': [
         '((e^(iø) + e^(-iø))/2 = ?|cosø', 
         'What is the condition whereby newtons method cannot be applied?|f prime(x0)=0',
         'Integrate 1/(a^2 + (bx+c)^2) wrt x |arctan((bx+c)/a)/ab +D', 
         'Find the two values of z whereby z^2 -2z+ (5/2)=0 (Hint: Since all the coefficient of the function are real and z=a+bi is a root, then z=a-bi must be another root|z= 1+ i√(3/2), z= 1-i√(3/2)',
         '((e^(iø) - e^(-iø))/2 = ?|sin ø',
         'True or False: If the limit of a sequence when n goes to infinity is non-zero, then the series diverges.|True',
         'Find the intergration of 1/(1+x^2) wrt x from x= -infinity to x= infinity |pi',
         'True or False: Since f^(-1)f(x)=x and ff^-1(x)=x , hence f^(-1)f(x)=ff^-1(x).|False since they may have different domains',
         'Assume f(x) is an odd function and that f prime(5)=1. What is the value of f prime (-5)? |1',
         'Find the limit of (x^3 -8)/(x-2) when x tends to 2.|12']

     }

shuffle(ma['easy'])
shuffle(ma['medium'])
shuffle(ma['hard'])

ctd = {'easy': [ 
    'Write the correct syntax to output "Hello World" in Python? |print("Hello World")',
    'How to create a variable x with the numeric value of integer 5?|x= int(5)', 
    'What is the correct syntax to print the output of the type of a variable x or object in Python?|print(type(x))', 
    'What is the syntax to create a function in Python? |def myFunction():', 
    'What is a correct syntax to return the first character in a string "Hello"?|x= "Hello”[0]', 
    'Which method can be used to return a string in upper case letters?|upper()', 
    'Which method can be used to replace parts of a string?|replace()', 
    'Which operator can be used to compare two values?|==', 
    'True or False: Dictionary is a collection that is ordered, changeable, and allows duplicate members. |False', 
    'Which method can be used to convert a number to a float number?|float()'
],
       
     'medium':[
         'Which statement is used to stop a loop?|stop', 
         '''a_dict = {'color': 'blue', 'fruit': 'apple', 'pet': 'dog'}
         for key in a_dict:
    print(key) |color, fruit, pet''',
    'True or False: If you just need to work with the keys of a dictionary, then you can use .keys(), which is a method that returns a new view object containing the dictionary’s keys.|True', 
    '''It’s common to only use the values to iterate through a dictionary in Python. One way to do that is to use .values(). What is correct way to use the function given the following dictionary called a_dict?
    a_dict = {'color': 'blue', 'fruit': 'apple', 'pet': 'dog'}|a_dict.values()''', 
    'What signifies the end of a statement block or suite in Python?|A line that is indented less than the previous line', 
    ''' True or False: These represent the same list:
    ['a', 'b', 'c']
    ['c', 'a', 'b'] |False''',
    ''' a = ['foo', 'bar', 'baz', 'qux', 'quux', 'corge']
    True or False: a[:]=a |False''', 
    ''' a = 3
    result = a == 2 or 5  
    print(result)
    What will you see on the screen? |5''', 
    '''y = print("hello")
    print(y)
    What will you see on the screen? |hello None''', 
    '''scores = [ 96,72,75,80,85,53,59,90,35]
    print (scores[-3])
    What will you see on the screen? |59'''
],
     'hard': [
    '''def some_function(x):
        a = 2*x
        return a 
    a = 5
    b = some_function(a)
    print(a)
    What will you see on the screen? |5''', 
    '''def next_function(a):
        a = 8
        return a
    a = 20
    print( next_function(a) )
    What will you see on the screen? |8''', 
    '''total=0
    for k in range(7):
        total= total + k**2
    print(total)
    What will you see on the screen? |91''', 
    '''number = [28,35,42,59,61]
    for number in number:
        if number > largest:
            largest = number
    print (largest)
    Fill in the blank to display '61' on the screen. |largest = -1''', 
    '''s = "amazing"
    ex = "!!"
    print(s+ex*3)
    What will you see on the screen? |amazing!!!!!!''', 
    '''a = "I love python"
    b = ________
    print (b[1])
    Fill in the blank in order to display 'love' on the screen |a.split()''', 
    '''t = "can the apple stay with you"
    print (t_____)
    Fill in the blanks, such that 'apple' is shown on the screen. |[8:13]''', 
    '''Suppose you have the following tuple:
    t = ('foo', 'bar', 'baz')
    what is the statement that replaces the second element ('bar') with 'qux'? |tuple can't be modified''', 
    '''True or False: 
    a = [1, 2, 3, 4, 5]
    a.append(['d','e'])
    a= ['a','b','c','d','e'] |False''', 
    '''x = [10, [3.141, 20, [30, 'baz', 2.718]], 'foo']
    What expression returns the list ['baz', 2.718] |x[1][2][1:3]''']

      }

shuffle(ctd['easy'])
shuffle(ctd['medium'])
shuffle(ctd['hard'])



def team():
    global team1
    global team2
    
    team1 = team1 + input('Team 1, please enter your team name: > ')
    team2 = team2 + input('Team 2, please enter your team name: > ')
    points()
    

def engine():
    a = input("Please type 'start' to begin the game. > ")
    if a.lower() == 'start':
        team()
        
        
    else:
        engine()
        


        
def points():
    
    global n
    global team1
    global team2
    global score1
    global score2

    while score1 < 200 and score2 < 200:
        
        
        if n % 2 == 0:
            print(f'{team1} please choose a category.')
            print(f'{team1} score: {score1}')
            print(f'{team2} score: {score2}')


        else:
            print(f'{team2} please choose a category.')
            print(f'{team1} score: {score1}')
            print(f'{team2} score: {score2}')
        choose_category()
                  
   
    if score1 >= 200:
        print(f"{team1} score: {score1}")
        print(f"Congratulations {team1}! You win! \nToo bad {team2}, you LOSE!")
    elif score2 >= 200:
        print(f"{team2} score: {score2}")
        print(f"Congratulations {team2}! You win! \nToo bad {team1}, you LOSE!")

    
def choose_category():
    subject = input("""Please select a subject from this list:
    physical world, modelling and analysis or computational thinking for design.
    > """)
    if subject.lower() == 'physical world' or subject.lower() == 'pw':
        difficulty_pw()
        
    elif subject.lower() == 'modelling and analysis' or subject.lower() == 'ma':
        difficulty_ma()
        
    elif subject.lower() == 'computational thinking for design' or subject.lower() == 'cdt' or subject.lower() == 'ctd':
        difficulty_ctd()
        
    else:
        print("""
        This category does not exist.
        """)
        choose_category()
        
        
        
def difficulty_pw():
    
    global score1
    global score2
    global acceptable_difficulty
    global difficulty_points
    global n
    
    diff = input("""
    Choose your difficulty:
    Easy, medium or hard?
    > 
    """)
    diff = diff.lower()
      
    if diff in acceptable_difficulty:
        if len(pw[diff]) > 0:
            
            question, answer = pw[diff][0].split('|')
            print(question)
            user_ans = input("> ")

            if answer in user_ans:
                print("Correct!")

                if n % 2 == 0:
                    score1 = score1 + difficulty_points[diff]
                        
                elif n % 2 == 1:
                    score2 = score2 + difficulty_points[diff]
                n += 1
                        
            else:
                print("Wrong! You'll get it next time!")
                print(f"""
                Please review the answer:
                {answer}
                """)
                n += 1


            del pw[diff][0]
        else:
            print("Sorry, the difficulty you selected for physical world does not have any questions left.\nPlease choose another subject or difficulty.")
            choose_category()  
    else:
        difficulty_pw()
    

        
def difficulty_ma():
    
    global score1
    global score2
    global acceptable_difficulty
    global difficulty_points
    global n
    
    diff = input("""
    Choose your difficulty:
    Easy, medium or hard?
    > 
    """)
    diff = diff.lower()
      
    if diff in acceptable_difficulty:
        if len(ma[diff]) > 0:
            
            question, answer = ma[diff][0].split('|')
            print(question)
            user_ans = input("> ")

            if answer in user_ans:
                print("Correct!")

                if n % 2 == 0:
                    score1 = score1 + difficulty_points[diff]
                        
                elif n % 2 == 1:
                    score2 = score2 + difficulty_points[diff]
                n += 1
                        
            else:
                print("Wrong! You'll get it next time!")
                print(f"""
                Please review the answer:
                {answer}
                """)
                n += 1


            del ma[diff][0]
        else:
            print("Sorry, the difficulty you selected for modelling and analysis does not have any questions left.\nPlease choose another subject or difficulty.")
            choose_category()  
    else:
        difficulty_ma()
        
        
def difficulty_ctd():
    
    global score1
    global score2
    global acceptable_difficulty
    global difficulty_points
    global n
    
    diff = input("""
    Choose your difficulty:
    Easy, medium or hard?
    > 
    """)
    diff = diff.lower()
      
    if diff in acceptable_difficulty:
        if len(ctd[diff]) > 0:
            
            question, answer = ctd[diff][0].split('|')
            print(question)
            user_ans = input("> ")

            if answer in user_ans:
                print("Correct!")

                if n % 2 == 0:
                    score1 = score1 + difficulty_points[diff]
                        
                elif n % 2 == 1:
                    score2 = score2 + difficulty_points[diff]
                n += 1
                        
            else:
                print("Wrong! You'll get it next time!")
                print(f"""
                Please review the answer:
                {answer}
                """)
                n += 1


            del ctd[diff][0]
        else:
            print("Sorry, the difficulty you selected for computational thinking for design does not have any questions left.\nPlease choose another subject or difficulty.")
            choose_category()  
    else:
        difficulty_ctd()

        

engine()
# Out:
# Please type 'start' to begin the game. > stasd
# Please type 'start' to begin the game. > start
# Team 1, please enter your team name: > quit
# Team 2, please enter your team name: > now
# quit please choose a category.
# quit score: 0
# now score: 0
